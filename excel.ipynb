# %%
import xlsxwriter

# %%
extrato = [
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/01/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/01/2022', 'valor': 4645.51},
  {'nome': 'tarifa bancaria cesta exclusive','data': '15/02/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '21/02/2022', 'valor': 3777.41},
  {'nome': 'tarifa bancaria cesta exclusive','data': '16/03/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '21/03/2022', 'valor': 3093.26},
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/01/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/01/2022', 'valor': 4645.51},
  {'nome': 'tarifa bancaria cesta exclusive','data': '15/02/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '21/02/2022', 'valor': 3777.41},
  {'nome': 'tarifa bancaria cesta exclusive','data': '16/03/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '21/03/2022', 'valor': 3093.26},
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/04/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/04/2022', 'valor': 2952.52},
  {'nome': 'tarifa bancaria cesta exclusive','data': '13/05/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/05/2022', 'valor': 3161.41},
  {'nome': 'tarifa bancaria cesta exclusive','data': '15/06/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/06/2022', 'valor': 3814.06},
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/07/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/07/2022', 'valor': 4042.29},
  {'nome': 'tarifa bancaria cesta exclusive','data': '17/08/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '22/08/2022', 'valor': 2897.59},
  {'nome': 'tarifa bancaria cesta exclusive','data': '15/09/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/09/2022', 'valor': 2387.07},
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/10/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/10/2022', 'valor': 2593.73},
  {'nome': 'tarifa bancaria cesta exclusive','data': '18/11/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '21/11/2022', 'valor': 2633.42},
  {'nome': 'tarifa bancaria cesta exclusive','data': '15/12/2022','valor': 68.8},
  {'nome': 'gastos cartao de credito', 'data': '20/12/2023', 'valor': 3104.78}
]
list_words = [
    'TARIFA BANCARIA Cesta Exclusive',
    'GASTOS CARTAO DE CREDITO'
]

# %%
def Mes (data) :
    aux = data.split('/')
    mes = int(aux[0])
    match(mes):
        case 1: return 'Jan ' + aux[1]
        case 2: return 'Fev ' + aux[1]
        case 3: return 'Mar ' + aux[1]
        case 4: return 'Abr ' + aux[1]
        case 5: return 'Mai ' + aux[1]
        case 6: return 'Jun ' + aux[1]
        case 7: return 'Jul ' + aux[1]
        case 8: return 'Ago ' + aux[1]
        case 9: return 'Set ' + aux[1]
        case 10: return 'Out ' + aux[1]
        case 11: return 'Nov ' + aux[1]
        case 12: return 'Dez ' + aux[1]

# %%
firstYear = extrato[0]['data'][6:]
lastYear = extrato[-1]['data'][6:]
anos = int(firstYear) - int(lastYear) + 1
for i in range(anos):
    print(1)

# %%
dados = {}
firstYear = int(extrato[0]['data'][6:])
lastYear = int(extrato[-1]['data'][6:])
qtdAnos = lastYear - firstYear  + 1
for i in range(len(list_words)):
    anos = {}
    for j in range(qtdAnos):
        anos[str(firstYear + j)] = {
                "Jan": 0,
                "Fev": 0,
                "Mar": 0,
                "Abr": 0,
                "Mai": 0,
                "Jun": 0,
                "Jul": 0,
                "Ago": 0,
                "Set": 0,
                "Out": 0,
                "Nov": 0,
                "Dez": 0
            }
    dados[list_words[i].lower()] = [anos]
    
dados
# Out:
# {'tarifa bancaria cesta exclusive': [{'2022': {'Jan': 0,
#     'Fev': 0,
#     'Mar': 0,
#     'Abr': 0,
#     'Mai': 0,
#     'Jun': 0,
#     'Jul': 0,
#     'Ago': 0,
#     'Set': 0,
#     'Out': 0,
#     'Nov': 0,
#     'Dez': 0},
#    '2023': {'Jan': 0,
#     'Fev': 0,
#     'Mar': 0,
#     'Abr': 0,
#     'Mai': 0,
#     'Jun': 0,
#     'Jul': 0,
#     'Ago': 0,
#     'Set': 0,
#     'Out': 0,
#     'Nov': 0,
#     'Dez': 0}}],
#  'gastos cartao de credito': [{'2022': {'Jan': 0,
#     'Fev': 0,
#     'Mar': 0,
#     'Abr': 0,
#     'Mai': 0,
#     'Jun': 0,
#     'Jul': 0,
#     'Ago': 0,
#     'Set': 0,
#     'Out': 0,
#     'Nov': 0,
#     'Dez': 0},
#    '2023': {'Jan': 0,
#     'Fev': 0,
#     'Mar': 0,
#     'Abr': 0,
#     'Mai': 0,
#     'Jun': 0,
#     'Jul': 0,
#     'Ago': 0,
#     'Set': 0,
#     'Out': 0,
#     'Nov': 0,
#     'Dez': 0}}]}

# %%
dados['tarifa bancaria cesta exclusive'][0]['2022']
# Out:
# {'Jan': 0,
#  'Fev': 0,
#  'Mar': 0,
#  'Abr': 0,
#  'Mai': 0,
#  'Jun': 0,
#  'Jul': 0,
#  'Ago': 0,
#  'Set': 0,
#  'Out': 0,
#  'Nov': 0,
#  'Dez': 0}

# %%
for i, item in enumerate(extrato):
    pass

print(dados[extrato[0]['nome']][0]['2022'])
# Out:
# {'Jan': 0, 'Fev': 0, 'Mar': 0, 'Abr': 0, 'Mai': 0, 'Jun': 0, 'Jul': 0, 'Ago': 0, 'Set': 0, 'Out': 0, 'Nov': 0, 'Dez': 0}

# %%
# workbook = xlsxwriter.Workbook('hello.xlsx')
 
# worksheet = workbook.add_worksheet()
 
# row = 0
# col = 0

# for word in list_words:
#     aux = []
#     worksheet.merge_range(row,col,row,col+1, word)
#     row += 1
#     for i,ext in enumerate(extrato):
#         if (word.lower() in ext['nome']):
#             for m in range(1,13):
#                 if (m == int(extrato[i]['data'][3:5])):
#                     worksheet.write(row, col, Mes(extrato[i]['data'][3:]))
#                     worksheet.write(row, col + 1, ext['valor'])
#             row += 1
#         else :
#             aux.append(ext)
#         if (i+1 == len(extrato)): 
#             worksheet.write(row, col, 'Total')
#             worksheet.write(row, col + 1, 0.0)
#             row += 2
#     extrato = aux

# workbook.close()

# %%
# Mes(extrato[4][0][3:])

# %%
extrato2 = [
    ['18/01/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/01/2022', 'gastos cartao de credito', 4645.51],
    ['15/02/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['21/02/2022', 'gastos cartao de credito', 3777.41],
    ['16/03/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['21/03/2022', 'gastos cartao de credito', 3093.26],
    ['18/04/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/04/2022', 'gastos cartao de credito', 2952.52],
    ['13/05/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/05/2022', 'gastos cartao de credito', 3161.41],
    ['15/06/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/06/2022', 'gastos cartao de credito', 3814.06],
    ['18/07/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/07/2022', 'gastos cartao de credito', 4042.29],
    ['17/08/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['22/08/2022', 'gastos cartao de credito', 2897.59],
    ['15/09/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/09/2022', 'gastos cartao de credito', 2387.07],
    ['18/10/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/10/2022', 'gastos cartao de credito', 2593.73],
    ['18/11/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['21/11/2022', 'gastos cartao de credito', 2633.42],
    ['15/12/2022', 'tarifa bancaria cesta exclusive', 68.8],
    ['20/12/2022', 'gastos cartao de credito', 3104.78],
]
list_words2 = [
    'TARIFA BANCARIA',
    'GASTOS CARTAO DE CREDITO'
]

# %%
for word in list_words2:
    aux = []
    for ext in extrato2:
        if(word.lower() in ext[1]):
            print(ext)
        else :
            aux.append(ext)
    extrato2 = aux
# Out:
# ['18/01/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['15/02/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['16/03/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['18/04/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['13/05/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['15/06/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['18/07/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['17/08/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['15/09/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['18/10/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['18/11/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['15/12/2022', 'tarifa bancaria cesta exclusive', 68.8]
# ['20/01/2022', 'gastos cartao de credito', 4645.51]
# ['21/02/2022', 'gastos cartao de credito', 3777.41]
# ['21/03/2022', 'gastos cartao de credito', 3093.26]
# ['20/04/2022', 'gastos cartao de credito', 2952.52]
# ['20/05/2022', 'gastos cartao de credito', 3161.41]
# ...
