# %%
from time import time
import PyPDF2
import re

pdf_file = './assets/1690395695539.pdf'
words_filter = {
    'words[0][word]': 'PACOTE DE SERVICOS',
    'words[1][word]': 'teste de erro',
}

# %%
phrase_filter = ''
dict_words = dict(words_filter)
for i, word in enumerate(dict_words.values()):
    if (i == len(dict_words)-1) : 
        phrase_filter = phrase_filter + ' ' + word.lower() + ' '
    else : 
        phrase_filter = phrase_filter +  ' ' + word.lower() + ' |'

reader = PyPDF2.PdfReader(pdf_file)
number_of_pages = len(reader.pages)

phrase_filter
# Out:
# ' pacote de servicos | teste de erro '

# %%
text = []

for i in range(number_of_pages):
    page = reader.pages[i]
    subtext = page.extract_text()
    subtext = subtext.replace("\n", " ")
    subtext = subtext.lower()
    padrao = re.compile('[ ]+')
    subtext = re.sub(padrao, ' ', subtext)
    text.append(subtext)

text[0]
# Out:
# 'bradesco celular data: 26/07/2023 - 15h21 nome: aglair braga de oliveira extrato de: agência: 3716 | conta: 9582-6 | movimentações entre: 01/01/2021 e 31/12/2021 folha: 1/4 data histórico docto. crédito (r$) débito (r$) saldo (r$) 01/03/2021 saldo anterior 0,00 25/03/2021 inss 253716 1.100,00 1.100,00 05/04/2021 saque outra agencia 1012467 -1.100,00 0,00 26/04/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10421 -13,60 1.086,40 03/05/2021 saque outra agencia 1012467 -1.080,00 6,40 14/05/2021pacote de servicos vr.parcial padronizado prior30521 -6,40 0,00 25/05/2021 inss 253716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i30521 -7,20 1.642,80 01/06/2021saque c/c bdn ag02467maq019605seq08733010609469605733 -1.640,00 2,80 15/06/2021pacote de servicos vr.parcial padronizado prior10621 -2,80 -0,00 24/06/2021 inss 243716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i10621 -10,80 1.639,20 01/07/2021saque c/c bdn ag03739maq010849seq0223901071014849239 -1.630,00 9,20 15/07/2021pacote de servicos vr.parcial padronizado prior10721 -9,20 0,00 26/07/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10721 -4,40 1.095,60'

# %%
def nome (n):
    array = n.split(" ")
    array.pop(0)
    array.pop(-1)
    return (' '.join(array)).title()

padrao = re.compile(r'^[a-z]+\s|nome:[a-z\s]+extrato|agência: [\d]+|conta: [\d-]+')
banco = re.findall(padrao,text[0])

infos = {
    'banco': banco[0].title(),
    'nome': nome(banco[1]),
    'agencia': banco[2],
    'conta': banco[3]
}

infos
# Out:
# {'banco': 'Bradesco ',
#  'nome': 'Aglair Braga De Oliveira',
#  'agencia': 'agência: 3716',
#  'conta': 'conta: 9582-6'}

# %%
for i in range(number_of_pages):
    padrao = re.compile('bradesco[\s\w\W]+saldo \(r\$\)')
    titulo = re.findall(padrao, text[i])
    text[i] = text[i].replace(titulo[0], '')

texto = ''

for txt in text:
    texto = texto + txt

texto
# Out:
# ' 01/03/2021 saldo anterior 0,00 25/03/2021 inss 253716 1.100,00 1.100,00 05/04/2021 saque outra agencia 1012467 -1.100,00 0,00 26/04/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10421 -13,60 1.086,40 03/05/2021 saque outra agencia 1012467 -1.080,00 6,40 14/05/2021pacote de servicos vr.parcial padronizado prior30521 -6,40 0,00 25/05/2021 inss 253716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i30521 -7,20 1.642,80 01/06/2021saque c/c bdn ag02467maq019605seq08733010609469605733 -1.640,00 2,80 15/06/2021pacote de servicos vr.parcial padronizado prior10621 -2,80 -0,00 24/06/2021 inss 243716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i10621 -10,80 1.639,20 01/07/2021saque c/c bdn ag03739maq010849seq0223901071014849239 -1.630,00 9,20 15/07/2021pacote de servicos vr.parcial padronizado prior10721 -9,20 0,00 26/07/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10721 -4,40 1.095,60 02/08/2021saque c/c banco24horas 00013454 01081049108197 -1.000,00 95,60 saque c/c banco24horas 00013454 01081051108201 -90,00 5,60 13/08/2021pacote de servicos vr.parcial padronizado prior20821 -5,60 -0,00 25/08/2021 inss 253716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i20821 -8,00 1.092,00 01/09/2021saque c/c banco24horas 00013454 01092049109067 -1.000,00 92,00 saque c/c banco24horas 00013454 01092053109073 -90,00 2,00 15/09/2021pacote de servicos vr.parcial padronizado prior10921 -2,00 0,00 24/09/2021 inss 243716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10921 -11,60 1.088,40 01/10/2021saque c/c banco24horas 00013454 01100828110569 -1.000,00 88,40 saque c/c banco24horas 00013454 01100829110571 -80,00 8,40 15/10/2021pacote de servicos vr.parcial padronizado prior11021 -8,40 0,00 20/10/2021ted-transf elet dispon remet.banco pan8522214 13.164,29 13.164,29 ted-transf elet dispon remet.banco pan8542588 1.232,00 14.396,29 pacote de servicos padronizado prioritarios i11021 -5,20 14.391,09 25/10/2021 inss 253716 1.100,00 15.491,09 04/11/2021saque c/c bdn ag02467maq003411seq09295041112173411295 -1.090,00 14.401,09 saque outra agencia 1042467 -14.396,29 4,80 12/11/2021pacote de servicos vr.parcial padronizado prior11121 -4,80 -0,00 24/11/2021 inss 243716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i11121 -8,80 1.050,23 01/12/2021saque com cartao cb especie3716076 -1.050,00 0,23 15/12/2021pacote de servicos vr.parcial padronizado prior11221 -0,23 -0,00 23/12/2021 inss 233716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i11221 -13,37 1.045,66 total 26.414,35 -25.368,69 1.045,66 14/07/2023 saldo anterior 0,00 25/07/2023 inss 253716 899,04 899,04 pacote de servicos padronizado prioritarios i30723 -6,20 892,84 26/07/2023 saque banco24horas 316242 -890,00 2,84 total 899,04 -896,20 2,84'

# %%
padrao = re.compile('\d{2}/\d{2}/\d{4}')

for data in re.finditer(padrao, texto):
    index = data.span()[0]
    texto = texto[:index-1] + '\n' + texto[index:]

texto = texto.split('\n')

texto
# Out:
# ['',
#  '01/03/2021 saldo anterior 0,00',
#  '25/03/2021 inss 253716 1.100,00 1.100,00',
#  '05/04/2021 saque outra agencia 1012467 -1.100,00 0,00',
#  '26/04/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10421 -13,60 1.086,40',
#  '03/05/2021 saque outra agencia 1012467 -1.080,00 6,40',
#  '14/05/2021pacote de servicos vr.parcial padronizado prior30521 -6,40 0,00',
#  '25/05/2021 inss 253716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i30521 -7,20 1.642,80',
#  '01/06/2021saque c/c bdn ag02467maq019605seq08733010609469605733 -1.640,00 2,80',
#  '15/06/2021pacote de servicos vr.parcial padronizado prior10621 -2,80 -0,00',
#  '24/06/2021 inss 243716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i10621 -10,80 1.639,20',
#  '01/07/2021saque c/c bdn ag03739maq010849seq0223901071014849239 -1.630,00 9,20',
#  '15/07/2021pacote de servicos vr.parcial padronizado prior10721 -9,20 0,00',
#  '26/07/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10721 -4,40 1.095,60',
#  '02/08/2021saque c/c banco24horas 00013454 01081049108197 -1.000,00 95,60 saque c/c banco24horas 00013454 01081051108201 -90,00 5,60',
#  '13/08/2021pacote de servicos vr.parcial padronizado prior20821 -5,60 -0,00',
#  '25/08/2021 inss 253716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i20821 -8,00 1.092,00',
#  '01/09/2021saque c/c banco24horas 00013454 01092049109067 -1.000,00 92,00 saque c/c banco24horas 00013454 01092053109073 -90,00 2,00',
#  '15/09/2021pacote de servicos vr.parcial padronizado prior10921 -2,00 0,00',
#  '24/09/2021 inss 243716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i10921 -11,60 1.088,40',
#  '01/10/2021saque c/c banco24horas 00013454 01100828110569 -1.000,00 88,40 saque c/c banco24horas 00013454 01100829110571 -80,00 8,40',
#  '15/10/2021pacote de servicos vr.parcial padronizado prior11021 -8,40 0,00',
#  '20/10/2021ted-transf elet dispon remet.banco pan8522214 13.164,29 13.164,29 ted-transf elet dispon remet.banco pan8542588 1.232,00 14.396,29 pacote de servicos padronizado prioritarios i11021 -5,20 14.391,09',
#  '25/10/2021 inss 253716 1.100,00 15.491,09',
#  '04/11/2021saque c/c bdn ag02467maq003411seq09295041112173411295 -1.090,00 14.401,09 saque outra agencia 1042467 -14.396,29 4,80',
#  '12/11/2021pacote de servicos vr.parcial padronizado prior11121 -4,80 -0,00',
#  '24/11/2021 inss 243716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i11121 -8,80 1.050,23',
#  '01/12/2021saque com cartao cb especie3716076 -1.050,00 0,23',
#  '15/12/2021pacote de servicos vr.parcial padronizado prior11221 -0,23 -0,00',
#  '23/12/2021 inss 233716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i11221 -13,37 1.045,66 total 26.414,35 -25.368,69 1.045,66',
#  '14/07/2023 saldo anterior 0,00',
#  '25/07/2023 inss 253716 899,04 899,04 pacote de servicos padronizado prioritarios i30723 -6,20 892,84',
#  '26/07/2023 saque banco24horas 316242 -890,00 2,84 total 899,04 -896,20 2,84']

# %%
padrao = re.compile('[a-z][0-9]|[0-9][a-z]')

for i, txt in enumerate(texto):
    for j, x in enumerate(re.finditer(padrao, txt)):
        sep = x.group()[0]+' '+x.group()[1]
        posicao = x.span()[0] + j
        texto[i] = texto[i][:posicao] + sep + texto[i][posicao+2:]

texto
# Out:
# ['',
#  '01/03/2021 saldo anterior 0,00',
#  '25/03/2021 inss 253716 1.100,00 1.100,00',
#  '05/04/2021 saque outra agencia 1012467 -1.100,00 0,00',
#  '26/04/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10421 -13,60 1.086,40',
#  '03/05/2021 saque outra agencia 1012467 -1.080,00 6,40',
#  '14/05/2021 pacote de servicos vr.parcial padronizado prior 30521 -6,40 0,00',
#  '25/05/2021 inss 253716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i 30521 -7,20 1.642,80',
#  '01/06/2021 saque c/c bdn ag 02467 maq 019605 seq 08733010609469605733 -1.640,00 2,80',
#  '15/06/2021 pacote de servicos vr.parcial padronizado prior 10621 -2,80 -0,00',
#  '24/06/2021 inss 243716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i 10621 -10,80 1.639,20',
#  '01/07/2021 saque c/c bdn ag 03739 maq 010849 seq 0223901071014849239 -1.630,00 9,20',
#  '15/07/2021 pacote de servicos vr.parcial padronizado prior 10721 -9,20 0,00',
#  '26/07/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10721 -4,40 1.095,60',
#  '02/08/2021 saque c/c banco 24 horas 00013454 01081049108197 -1.000,00 95,60 saque c/c banco 24 horas 00013454 01081051108201 -90,00 5,60',
#  '13/08/2021 pacote de servicos vr.parcial padronizado prior 20821 -5,60 -0,00',
#  '25/08/2021 inss 253716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 20821 -8,00 1.092,00',
#  '01/09/2021 saque c/c banco 24 horas 00013454 01092049109067 -1.000,00 92,00 saque c/c banco 24 horas 00013454 01092053109073 -90,00 2,00',
#  '15/09/2021 pacote de servicos vr.parcial padronizado prior 10921 -2,00 0,00',
#  '24/09/2021 inss 243716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10921 -11,60 1.088,40',
#  '01/10/2021 saque c/c banco 24 horas 00013454 01100828110569 -1.000,00 88,40 saque c/c banco 24 horas 00013454 01100829110571 -80,00 8,40',
#  '15/10/2021 pacote de servicos vr.parcial padronizado prior 11021 -8,40 0,00',
#  '20/10/2021 ted-transf elet dispon remet.banco pan 8522214 13.164,29 13.164,29 ted-transf elet dispon remet.banco pan 8542588 1.232,00 14.396,29 pacote de servicos padronizado prioritarios i 11021 -5,20 14.391,09',
#  '25/10/2021 inss 253716 1.100,00 15.491,09',
#  '04/11/2021 saque c/c bdn ag 02467 maq 003411 seq 09295041112173411295 -1.090,00 14.401,09 saque outra agencia 1042467 -14.396,29 4,80',
#  '12/11/2021 pacote de servicos vr.parcial padronizado prior 11121 -4,80 -0,00',
#  '24/11/2021 inss 243716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i 11121 -8,80 1.050,23',
#  '01/12/2021 saque com cartao cb especie 3716076 -1.050,00 0,23',
#  '15/12/2021 pacote de servicos vr.parcial padronizado prior 11221 -0,23 -0,00',
#  '23/12/2021 inss 233716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i 11221 -13,37 1.045,66 total 26.414,35 -25.368,69 1.045,66',
#  '14/07/2023 saldo anterior 0,00',
#  '25/07/2023 inss 253716 899,04 899,04 pacote de servicos padronizado prioritarios i 30723 -6,20 892,84',
#  '26/07/2023 saque banco 24 horas 316242 -890,00 2,84 total 899,04 -896,20 2,84']

# %%
filtro = []

padrao = re.compile(phrase_filter)

for txt in texto:
    tamanho = re.findall(padrao, txt)
    if (len(tamanho) > 0):
        filtro.append(txt)

filtro
# Out:
# ['26/04/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10421 -13,60 1.086,40',
#  '14/05/2021 pacote de servicos vr.parcial padronizado prior 30521 -6,40 0,00',
#  '25/05/2021 inss 253716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i 30521 -7,20 1.642,80',
#  '15/06/2021 pacote de servicos vr.parcial padronizado prior 10621 -2,80 -0,00',
#  '24/06/2021 inss 243716 1.650,00 1.650,00 pacote de servicos padronizado prioritarios i 10621 -10,80 1.639,20',
#  '15/07/2021 pacote de servicos vr.parcial padronizado prior 10721 -9,20 0,00',
#  '26/07/2021 inss 263716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10721 -4,40 1.095,60',
#  '13/08/2021 pacote de servicos vr.parcial padronizado prior 20821 -5,60 -0,00',
#  '25/08/2021 inss 253716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 20821 -8,00 1.092,00',
#  '15/09/2021 pacote de servicos vr.parcial padronizado prior 10921 -2,00 0,00',
#  '24/09/2021 inss 243716 1.100,00 1.100,00 pacote de servicos padronizado prioritarios i 10921 -11,60 1.088,40',
#  '15/10/2021 pacote de servicos vr.parcial padronizado prior 11021 -8,40 0,00',
#  '20/10/2021 ted-transf elet dispon remet.banco pan 8522214 13.164,29 13.164,29 ted-transf elet dispon remet.banco pan 8542588 1.232,00 14.396,29 pacote de servicos padronizado prioritarios i 11021 -5,20 14.391,09',
#  '12/11/2021 pacote de servicos vr.parcial padronizado prior 11121 -4,80 -0,00',
#  '24/11/2021 inss 243716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i 11121 -8,80 1.050,23',
#  '15/12/2021 pacote de servicos vr.parcial padronizado prior 11221 -0,23 -0,00',
#  '23/12/2021 inss 233716 1.059,03 1.059,03 pacote de servicos padronizado prioritarios i 11221 -13,37 1.045,66 total 26.414,35 -25.368,69 1.045,66',
#  '25/07/2023 inss 253716 899,04 899,04 pacote de servicos padronizado prioritarios i 30723 -6,20 892,84']

# %%
filtro2 = []

for txt in filtro:
    padraoData = re.compile(r'\d{2}/\d{2}/\d{4}')
    padrao = re.compile(r'\s?[a-z][0-9a-z\s\.]+[a-z0-9] [0-9]+ [0-9.,-]+ [0-9.,-]+\s?')
    data = re.findall(padraoData, txt)
    teste = re.findall(padrao, txt)
    for i in range(len(teste)):
        if (teste[i][0] == ' ') : filtro2.append(data[0]+teste[i])
        else : filtro2.append(data[0]+' '+teste[i])

filtro2
# Out:
# ['26/04/2021 inss 263716 1.100,00 1.100,00 ',
#  '26/04/2021 pacote de servicos padronizado prioritarios i 10421 -13,60 1.086,40',
#  '14/05/2021 pacote de servicos vr.parcial padronizado prior 30521 -6,40 0,00',
#  '25/05/2021 inss 253716 1.650,00 1.650,00 ',
#  '25/05/2021 pacote de servicos padronizado prioritarios i 30521 -7,20 1.642,80',
#  '15/06/2021 pacote de servicos vr.parcial padronizado prior 10621 -2,80 -0,00',
#  '24/06/2021 inss 243716 1.650,00 1.650,00 ',
#  '24/06/2021 pacote de servicos padronizado prioritarios i 10621 -10,80 1.639,20',
#  '15/07/2021 pacote de servicos vr.parcial padronizado prior 10721 -9,20 0,00',
#  '26/07/2021 inss 263716 1.100,00 1.100,00 ',
#  '26/07/2021 pacote de servicos padronizado prioritarios i 10721 -4,40 1.095,60',
#  '13/08/2021 pacote de servicos vr.parcial padronizado prior 20821 -5,60 -0,00',
#  '25/08/2021 inss 253716 1.100,00 1.100,00 ',
#  '25/08/2021 pacote de servicos padronizado prioritarios i 20821 -8,00 1.092,00',
#  '15/09/2021 pacote de servicos vr.parcial padronizado prior 10921 -2,00 0,00',
#  '24/09/2021 inss 243716 1.100,00 1.100,00 ',
#  '24/09/2021 pacote de servicos padronizado prioritarios i 10921 -11,60 1.088,40',
#  '15/10/2021 pacote de servicos vr.parcial padronizado prior 11021 -8,40 0,00',
#  '20/10/2021 transf elet dispon remet.banco pan 8522214 13.164,29 13.164,29 ',
#  '20/10/2021 transf elet dispon remet.banco pan 8542588 1.232,00 14.396,29 ',
#  '20/10/2021 pacote de servicos padronizado prioritarios i 11021 -5,20 14.391,09',
#  '12/11/2021 pacote de servicos vr.parcial padronizado prior 11121 -4,80 -0,00',
#  '24/11/2021 inss 243716 1.059,03 1.059,03 ',
#  '24/11/2021 pacote de servicos padronizado prioritarios i 11121 -8,80 1.050,23',
#  '15/12/2021 pacote de servicos vr.parcial padronizado prior 11221 -0,23 -0,00',
#  '23/12/2021 inss 233716 1.059,03 1.059,03 ',
#  '23/12/2021 pacote de servicos padronizado prioritarios i 11221 -13,37 1.045,66 ',
#  '25/07/2023 inss 253716 899,04 899,04 ',
#  '25/07/2023 pacote de servicos padronizado prioritarios i 30723 -6,20 892,84']

# %%
filtro = []

padrao = re.compile(phrase_filter)
for txt in filtro2:
    tamanho = re.findall(padrao, txt)
    if (len(tamanho) > 0):
        filtro.append(txt)

filtro
# Out:
# ['26/04/2021 pacote de servicos padronizado prioritarios i 10421 -13,60 1.086,40',
#  '14/05/2021 pacote de servicos vr.parcial padronizado prior 30521 -6,40 0,00',
#  '25/05/2021 pacote de servicos padronizado prioritarios i 30521 -7,20 1.642,80',
#  '15/06/2021 pacote de servicos vr.parcial padronizado prior 10621 -2,80 -0,00',
#  '24/06/2021 pacote de servicos padronizado prioritarios i 10621 -10,80 1.639,20',
#  '15/07/2021 pacote de servicos vr.parcial padronizado prior 10721 -9,20 0,00',
#  '26/07/2021 pacote de servicos padronizado prioritarios i 10721 -4,40 1.095,60',
#  '13/08/2021 pacote de servicos vr.parcial padronizado prior 20821 -5,60 -0,00',
#  '25/08/2021 pacote de servicos padronizado prioritarios i 20821 -8,00 1.092,00',
#  '15/09/2021 pacote de servicos vr.parcial padronizado prior 10921 -2,00 0,00',
#  '24/09/2021 pacote de servicos padronizado prioritarios i 10921 -11,60 1.088,40',
#  '15/10/2021 pacote de servicos vr.parcial padronizado prior 11021 -8,40 0,00',
#  '20/10/2021 pacote de servicos padronizado prioritarios i 11021 -5,20 14.391,09',
#  '12/11/2021 pacote de servicos vr.parcial padronizado prior 11121 -4,80 -0,00',
#  '24/11/2021 pacote de servicos padronizado prioritarios i 11121 -8,80 1.050,23',
#  '15/12/2021 pacote de servicos vr.parcial padronizado prior 11221 -0,23 -0,00',
#  '23/12/2021 pacote de servicos padronizado prioritarios i 11221 -13,37 1.045,66 ',
#  '25/07/2023 pacote de servicos padronizado prioritarios i 30723 -6,20 892,84']

# %%
extrato = []
nomes = []

for item in filtro:
    padrao = re.compile(r'\d{2}/\d{2}/\d{4}|[a-z][a-z\s\.]+[a-z]|-[0-9.,]+\s')
    teste = re.findall(padrao, item)
    extrato.append({ 
        "nome": teste[1],
        "data": teste[0], 
        "valor": float(teste[2][1:].replace('.', '').replace(',', '.'))
    })
    nomes.append(teste[1])
    
# print(len(extrato))
# extrato
list(set(nomes))
# Out:
# ['pacote de servicos padronizado prioritarios i',
#  'pacote de servicos vr.parcial padronizado prior']
